# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/streaming-interruption.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239464-lesson-1-streaming)

# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatOpenAI(model="gpt-4o", temperature=0) 

# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://langchain-ai.github.io/langgraph/how-tos/stream-values/) for [graph state](https://langchain-ai.github.io/langgraph/how-tos/stream-values/):
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content='Hello Lance! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 11, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BoO6nqmakQwwP9m2JkqWrNvxpvE9q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--effee6a5-2010-4b26-b486-b3635fa2d2ec-0', usage_metadata={'input_tokens': 11, 'output_tokens': 10, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hi Lance! How's it going? What can I do for you today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hello Lance! How can I assist you today?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://langchain-ai.github.io/langgraph/how-tos/streaming-from-final-node/#stream-outputs-from-the-final-node), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}, Data: {event['data']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph, Data: {'input': {'messages': [HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={})]}}
# Node: conversation. Type: on_chain_start. Name: conversation, Data: {'input': {'messages': [HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={}, id='dbc500e6-9070-462c-b483-d7bb737304fa'), AIMessage(content="The San Francisco 49ers are a professional American football team based in the San Francisco Bay Area. They compete in the National Football League (NFL) as a member of the league's National Football Conference (NFC) West division. Here are some key points about the team:\n\n1. **History and Establishment**: The 49ers were established in 1946 as a charter member of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the 10th oldest franchise in the NFL and the oldest major professional sports team in California.\n\n2. **Team Name and Colors**: The team is named after the prospectors who arrived in Northern California during the 1849 Gold Rush. The team's colors are red, gold, and white.\n\n3. **Stadium**: The 49ers play their home games at Levi's Stadium in Santa Clara, California, which they moved to in 2014. Before that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Success**: The 49ers have won five Super Bowl championships (in the 1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most successful teams in NFL history. They have also won numerous division titles and conference championships.\n\n5. **Notable Figures**: The team has had several Hall of Fame players and coaches, including Joe Montana, Jerry Rice, Steve Young, Ronnie Lott, and coach Bill Walsh. These individuals were instrumental in the team's success, particularly during the 1980s and 1990s.\n\n6. **Rivalries**: The 49ers have several notable rivalries, particularly with the Dallas Cowboys, Los Angeles Rams, and Seattle Seahawks. These rivalries have been fueled by competitive playoff matchups and divisional contests.\n\n7. **Recent Performance**: In recent years, the 49ers have experienced both ups and downs. They reached the Super Bowl in the 2019 season but lost to the Kansas City Chiefs. The team has been working to maintain competitiveness in the league with a mix of veteran leadership and young talent.\n\n8. **Community and Culture**: The 49ers are known for their strong fan base and community involvement. They have a rich tradition and are an integral part of the sports culture in the Bay Area.\n\nThe 49ers continue to be a prominent team in the NFL, with a focus on building a roster capable of competing for championships.", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, id='run--0022ee48-e143-42c1-930a-dd2e619a67c4'), HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={}, id='4ddd442c-f5b7-4578-8b34-f01d8b60636b')]}}
# Node: conversation. Type: on_chat_model_start. Name: ChatOpenAI, Data: {'input': {'messages': [[HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={}, id='dbc500e6-9070-462c-b483-d7bb737304fa'), AIMessage(content="The San Francisco 49ers are a professional American football team based in the San Francisco Bay Area. They compete in the National Football League (NFL) as a member of the league's National Football Conference (NFC) West division. Here are some key points about the team:\n\n1. **History and Establishment**: The 49ers were established in 1946 as a charter member of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the 10th oldest franchise in the NFL and the oldest major professional sports team in California.\n\n2. **Team Name and Colors**: The team is named after the prospectors who arrived in Northern California during the 1849 Gold Rush. The team's colors are red, gold, and white.\n\n3. **Stadium**: The 49ers play their home games at Levi's Stadium in Santa Clara, California, which they moved to in 2014. Before that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Success**: The 49ers have won five Super Bowl championships (in the 1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most successful teams in NFL history. They have also won numerous division titles and conference championships.\n\n5. **Notable Figures**: The team has had several Hall of Fame players and coaches, including Joe Montana, Jerry Rice, Steve Young, Ronnie Lott, and coach Bill Walsh. These individuals were instrumental in the team's success, particularly during the 1980s and 1990s.\n\n6. **Rivalries**: The 49ers have several notable rivalries, particularly with the Dallas Cowboys, Los Angeles Rams, and Seattle Seahawks. These rivalries have been fueled by competitive playoff matchups and divisional contests.\n\n7. **Recent Performance**: In recent years, the 49ers have experienced both ups and downs. They reached the Super Bowl in the 2019 season but lost to the Kansas City Chiefs. The team has been working to maintain competitiveness in the league with a mix of veteran leadership and young talent.\n\n8. **Community and Culture**: The 49ers are known for their strong fan base and community involvement. They have a rich tradition and are an integral part of the sports culture in the Bay Area.\n\nThe 49ers continue to be a prominent team in the NFL, with a focus on building a roster capable of competing for championships.", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, id='run--0022ee48-e143-42c1-930a-dd2e619a67c4'), HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={}, id='4ddd442c-f5b7-4578-8b34-f01d8b60636b')]]}}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' stor', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ied', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' franchise', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' League', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='NFL', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='),', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' known', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' rich', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' history', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' success', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' field', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=" Here's", additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' an', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' overview', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='Found', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ing', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Early', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Years', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' were', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' established', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='6', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' part', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' All', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='-Amer', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ica', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='AA', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='FC', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' joined', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' when', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' leagues', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' merged', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' They', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' oldest', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' major', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' professional', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' sports', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='Team', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Name', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Identity', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' name', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='"', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' nod', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' prospect', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ors', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='184', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Gold', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Rush', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Northern', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=" team's", additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' colors', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' red', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' gold', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' white', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' reflecting', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' gold', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' rush', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' theme', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='Home', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' plays', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' its', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' home', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' games', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Levi', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Santa', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' which', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' opened', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Prior', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' that', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' played', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Cand', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='lestick', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Park', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' from', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='197', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='Champ', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='ionship', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI, Data: {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}
# ...
# Node: conversation. Type: on_chain_stream. Name: conversation, Data: {'chunk': {'messages': AIMessage(content='The San Francisco 49ers are a storied franchise in the National Football League (NFL), known for their rich history and success on the field. Here\'s an overview of the team:\n\n1. **Founding and Early Years**: The 49ers were established in 1946 as part of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the oldest major professional sports team in California.\n\n2. **Team Name and Identity**: The name "49ers" is a nod to the prospectors of the 1849 Gold Rush in Northern California. The team\'s colors are red, gold, and white, reflecting the gold rush theme.\n\n3. **Home Stadium**: The team plays its home games at Levi\'s Stadium in Santa Clara, California, which opened in 2014. Prior to that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Achievements**: The 49ers have won five Super Bowl titles (1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most successful teams in NFL history. They have also secured numerous division titles and conference championships.\n\n5. **Legendary Figures**: The franchise has been home to several Hall of Fame players and coaches, including quarterback Joe Montana, wide receiver Jerry Rice, quarterback Steve Young, safety Ronnie Lott, and coach Bill Walsh. These figures were pivotal during the team\'s dominant years in the 1980s and 1990s.\n\n6. **Rivalries**: The 49ers have intense rivalries with teams like the Dallas Cowboys, Los Angeles Rams, and Seattle Seahawks. These rivalries are fueled by historic playoff battles and divisional competition.\n\n7. **Recent Performance**: The team has experienced a mix of successes and challenges in recent years. They reached the Super Bowl in the 2019 season but were defeated by the Kansas City Chiefs. The 49ers continue to build a competitive roster with a blend of experienced players and emerging talent.\n\n8. **Community and Fan Base**: The 49ers have a passionate fan base and are deeply involved in community initiatives. They are a significant part of the sports culture in the San Francisco Bay Area.\n\nOverall, the San Francisco 49ers are a team with a rich legacy and a commitment to excellence, both on and off the field. They continue to strive for success in the NFL, aiming to add more championships to their storied history.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}}
# Node: conversation. Type: on_chain_end. Name: conversation, Data: {'output': {'messages': AIMessage(content='The San Francisco 49ers are a storied franchise in the National Football League (NFL), known for their rich history and success on the field. Here\'s an overview of the team:\n\n1. **Founding and Early Years**: The 49ers were established in 1946 as part of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the oldest major professional sports team in California.\n\n2. **Team Name and Identity**: The name "49ers" is a nod to the prospectors of the 1849 Gold Rush in Northern California. The team\'s colors are red, gold, and white, reflecting the gold rush theme.\n\n3. **Home Stadium**: The team plays its home games at Levi\'s Stadium in Santa Clara, California, which opened in 2014. Prior to that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Achievements**: The 49ers have won five Super Bowl titles (1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most successful teams in NFL history. They have also secured numerous division titles and conference championships.\n\n5. **Legendary Figures**: The franchise has been home to several Hall of Fame players and coaches, including quarterback Joe Montana, wide receiver Jerry Rice, quarterback Steve Young, safety Ronnie Lott, and coach Bill Walsh. These figures were pivotal during the team\'s dominant years in the 1980s and 1990s.\n\n6. **Rivalries**: The 49ers have intense rivalries with teams like the Dallas Cowboys, Los Angeles Rams, and Seattle Seahawks. These rivalries are fueled by historic playoff battles and divisional competition.\n\n7. **Recent Performance**: The team has experienced a mix of successes and challenges in recent years. They reached the Super Bowl in the 2019 season but were defeated by the Kansas City Chiefs. The 49ers continue to build a competitive roster with a blend of experienced players and emerging talent.\n\n8. **Community and Fan Base**: The 49ers have a passionate fan base and are deeply involved in community initiatives. They are a significant part of the sports culture in the San Francisco Bay Area.\n\nOverall, the San Francisco 49ers are a team with a rich legacy and a commitment to excellence, both on and off the field. They continue to strive for success in the NFL, aiming to add more championships to their storied history.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}, 'input': {'messages': [HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={}, id='dbc500e6-9070-462c-b483-d7bb737304fa'), AIMessage(content="The San Francisco 49ers are a professional American football team based in the San Francisco Bay Area. They compete in the National Football League (NFL) as a member of the league's National Football Conference (NFC) West division. Here are some key points about the team:\n\n1. **History and Establishment**: The 49ers were established in 1946 as a charter member of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the 10th oldest franchise in the NFL and the oldest major professional sports team in California.\n\n2. **Team Name and Colors**: The team is named after the prospectors who arrived in Northern California during the 1849 Gold Rush. The team's colors are red, gold, and white.\n\n3. **Stadium**: The 49ers play their home games at Levi's Stadium in Santa Clara, California, which they moved to in 2014. Before that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Success**: The 49ers have won five Super Bowl championships (in the 1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most succe ...
# Node: . Type: on_chain_stream. Name: LangGraph, Data: {'chunk': {'conversation': {'messages': AIMessage(content='The San Francisco 49ers are a storied franchise in the National Football League (NFL), known for their rich history and success on the field. Here\'s an overview of the team:\n\n1. **Founding and Early Years**: The 49ers were established in 1946 as part of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the oldest major professional sports team in California.\n\n2. **Team Name and Identity**: The name "49ers" is a nod to the prospectors of the 1849 Gold Rush in Northern California. The team\'s colors are red, gold, and white, reflecting the gold rush theme.\n\n3. **Home Stadium**: The team plays its home games at Levi\'s Stadium in Santa Clara, California, which opened in 2014. Prior to that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Achievements**: The 49ers have won five Super Bowl titles (1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most successful teams in NFL history. They have also secured numerous division titles and conference championships.\n\n5. **Legendary Figures**: The franchise has been home to several Hall of Fame players and coaches, including quarterback Joe Montana, wide receiver Jerry Rice, quarterback Steve Young, safety Ronnie Lott, and coach Bill Walsh. These figures were pivotal during the team\'s dominant years in the 1980s and 1990s.\n\n6. **Rivalries**: The 49ers have intense rivalries with teams like the Dallas Cowboys, Los Angeles Rams, and Seattle Seahawks. These rivalries are fueled by historic playoff battles and divisional competition.\n\n7. **Recent Performance**: The team has experienced a mix of successes and challenges in recent years. They reached the Super Bowl in the 2019 season but were defeated by the Kansas City Chiefs. The 49ers continue to build a competitive roster with a blend of experienced players and emerging talent.\n\n8. **Community and Fan Base**: The 49ers have a passionate fan base and are deeply involved in community initiatives. They are a significant part of the sports culture in the San Francisco Bay Area.\n\nOverall, the San Francisco 49ers are a team with a rich legacy and a commitment to excellence, both on and off the field. They continue to strive for success in the NFL, aiming to add more championships to their storied history.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, id='run--d47f0864-c7b4-4d6a-be37-91d21d545d11')}}}
# Node: . Type: on_chain_end. Name: LangGraph, Data: {'output': {'messages': [HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={}, id='dbc500e6-9070-462c-b483-d7bb737304fa'), AIMessage(content="The San Francisco 49ers are a professional American football team based in the San Francisco Bay Area. They compete in the National Football League (NFL) as a member of the league's National Football Conference (NFC) West division. Here are some key points about the team:\n\n1. **History and Establishment**: The 49ers were established in 1946 as a charter member of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the 10th oldest franchise in the NFL and the oldest major professional sports team in California.\n\n2. **Team Name and Colors**: The team is named after the prospectors who arrived in Northern California during the 1849 Gold Rush. The team's colors are red, gold, and white.\n\n3. **Stadium**: The 49ers play their home games at Levi's Stadium in Santa Clara, California, which they moved to in 2014. Before that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Success**: The 49ers have won five Super Bowl championships (in the 1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most successful teams in NFL history. They have also won numerous division titles and conference championships.\n\n5. **Notable Figures**: The team has had several Hall of Fame players and coaches, including Joe Montana, Jerry Rice, Steve Young, Ronnie Lott, and coach Bill Walsh. These individuals were instrumental in the team's success, particularly during the 1980s and 1990s.\n\n6. **Rivalries**: The 49ers have several notable rivalries, particularly with the Dallas Cowboys, Los Angeles Rams, and Seattle Seahawks. These rivalries have been fueled by competitive playoff matchups and divisional contests.\n\n7. **Recent Performance**: In recent years, the 49ers have experienced both ups and downs. They reached the Super Bowl in the 2019 season but lost to the Kansas City Chiefs. The team has been working to maintain competitiveness in the league with a mix of veteran leadership and young talent.\n\n8. **Community and Culture**: The 49ers are known for their strong fan base and community involvement. They have a rich tradition and are an integral part of the sports culture in the Bay Area.\n\nThe 49ers continue to be a prominent team in the NFL, with a focus on building a roster capable of competing for championships.", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, id='run--0022ee48-e143-42c1-930a-dd2e619a67c4'), HumanMessage(content='Tell me about the 49ers NFL team', additional_kwargs={}, response_metadata={}, id='4ddd442c-f5b7-4578-8b34-f01d8b60636b'), AIMessage(content='The San Francisco 49ers are a storied franchise in the National Football League (NFL), known for their rich history and success on the field. Here\'s an overview of the team:\n\n1. **Founding and Early Years**: The 49ers were established in 1946 as part of the All-America Football Conference (AAFC) and joined the NFL in 1949 when the leagues merged. They are the oldest major professional sports team in California.\n\n2. **Team Name and Identity**: The name "49ers" is a nod to the prospectors of the 1849 Gold Rush in Northern California. The team\'s colors are red, gold, and white, reflecting the gold rush theme.\n\n3. **Home Stadium**: The team plays its home games at Levi\'s Stadium in Santa Clara, California, which opened in 2014. Prior to that, they played at Candlestick Park in San Francisco from 1971 to 2013.\n\n4. **Championships and Achievements**: The 49ers have won five Super Bowl titles (1981, 1984, 1988, 1989, and 1994 seasons), making them one of the most successful teams in NFL history. They have a ...

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' professional', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' American', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' football', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' based', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Bay', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Area', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' They', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' compete', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' League', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='NFL', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' member', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' league', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='N', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='FC', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' West', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' division', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' was', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' founded', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='6', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' charter', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' member', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' All', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-Amer', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ica', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='AA', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='FC', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' joined', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' when', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' leagues', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' merged', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='###', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Key', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Points', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='St', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='adium', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' play', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' home', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' games', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Levi', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Santa', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' which', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' moved', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Before', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' that', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' played', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Cand', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='lestick', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Park', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='Team', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Colors', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=" team's", additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' colors', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' red', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' gold', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' white', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='Masc', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ot', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content="'", additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' mascot', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' S', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ourd', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ough', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Sam', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='Champ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ionship', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' five', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' championships', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='Super', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' XVI', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' XIX', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' XX', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='III', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' XX', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='IV', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' XX', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='IX', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='),', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' most', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' successful', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' period', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' being', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' early', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='199', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='Not', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='able', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Players', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' had', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' several', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Hall', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Fame', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' players', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' including', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Joe', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Montana', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Jerry', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Rice', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Steve', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Young', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Ronnie', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' L', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ott', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Charles', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Haley', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='Co', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='aching', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Management', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' led', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' by', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' several', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' notable', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' coaches', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' including', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Bill', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Walsh', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' who', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' credited', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' popular', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='izing', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='West', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Coast', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Off', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ense', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='."', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' As', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='202', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' season', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' head', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' coach', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Kyle', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Shan', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ahan', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='R', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ival', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ries', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' notable', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' rival', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ries', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Seattle', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Seahawks', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Los', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Angeles', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Rams', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' historically', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Dallas', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Cowboys', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Green', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Bay', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Packers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='Recent', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Performance', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' In', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' recent', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' years', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' competitive', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' reaching', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' season', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' losing', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Kansas', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' City', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Chiefs', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' They', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' consistently', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' strong', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' contenders', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' NFC', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' under', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' leadership', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Kyle', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Shan', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ahan', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' general', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' manager', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' John', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' Lynch', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' known', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' rich', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' history', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' passionate', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' fan', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' base', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' significant', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' contributions', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' development', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content=' popularity', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, id='run--c9c5178d-d409-4516-968d-108c0951e3af')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# |The| San| Francisco| |49|ers| are| a| professional| American| football| team| based| in| the| San| Francisco| Bay| Area|.| They| compete| in| the| National| Football| League| (|NFL|)| as| a| member| club| of| the| league|'s| National| Football| Conference| (|N|FC|)| West| division|.| The| team| was| founded| in| |194|6| as| a| charter| member| of| the| All|-Amer|ica| Football| Conference| (|AA|FC|)| and| joined| the| NFL| in| |194|9| when| the| leagues| merged|.
#
# |###| Key| Points|:
#
# |-| **|St|adium|**|:| The| |49|ers| play| their| home| games| at| Levi|'s| Stadium| in| Santa| Clara|,| California|,| which| they| moved| to| in| |201|4|.| Before| that|,| they| played| at| Cand|lestick| Park| in| San| Francisco|.
#
# |-| **|Team| Colors|**|:| The| team's| colors| are| red|,| gold|,| and| white|.
#
# |-| **|Masc|ot|**|:| The| |49|ers|'| mascot| is| S|ourd|ough| Sam|.
#
# |-| **|Champ|ionship|s|**|:| The| |49|ers| have| won| five| Super| Bowl| championships| (|Super| Bowl| XVI|,| XIX|,| XX|III|,| XX|IV|,| and| XX|IX|),| with| their| most| successful| period| being| the| |198|0|s| and| early| |199|0|s|.
#
# |-| **|Not|able| Figures|**|:| The| team| has| had| several| Hall| of| Fame| players|,| including| Joe| Montana|,| Jerry| Rice|,| Steve| Young|,| Ronnie| L|ott|,| and| Charles| Haley|.| Bill| Walsh|,| the| legendary| head| coach|,| is| credited| with| developing| the| West| Coast| offense|,| which| became| a| staple| of| the| team's| success|.
#
# |-| **|R|ival|ries|**|:| The| |49|ers| have| notable| rival|ries| with| the| Seattle| Seahawks|,| Los| Angeles| Rams|,| and| historically| with| the| Dallas| Cowboys| and| Green| Bay| Packers|.
#
# |-| **|Recent| Performance|**|:| In| recent| years|,| the| |49|ers| have| been| competitive|,| reaching| the| Super| Bowl| in| the| |201|9| season| but| losing| to| the| Kansas| City| Chiefs|.| They| have| been| known| for| their| strong| defense| and| innovative| offensive| strategies| under| head| coach| Kyle| Shan|ahan|.
#
# |The| |49|ers| have| a| rich| history| and| a| passionate| fan| base|,| making| them| one| of| the| iconic| franchises| in| the| NFL|.||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
#
# The LangGraph API [supports editing graph state](https://langchain-ai.github.io/langgraph/cloud/how-tos/human_in_the_loop_edit_state/#initial-invocation).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()
assistants
# Out:
# [{'assistant_id': '6f6fce9a-b777-529d-9699-dd340ddec86c',
#   'graph_id': 'dynamic_breakpoints',
#   'config': {},
#   'metadata': {'created_by': 'system'},
#   'name': 'dynamic_breakpoints',
#   'created_at': '2025-07-01T05:32:30.641118+00:00',
#   'updated_at': '2025-07-01T05:32:30.641118+00:00',
#   'version': 1,
#   'description': None},
#  {'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'graph_id': 'agent',
#   'config': {},
#   'metadata': {'created_by': 'system'},
#   'name': 'agent',
#   'created_at': '2025-07-01T05:32:30.638827+00:00',
#   'updated_at': '2025-07-01T05:32:30.638827+00:00',
#   'version': 1,
#   'description': None}]

# %% [markdown]
# Let's [stream `values`](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_values/), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '1f056400-f31e-6ef0-8a30-d1536863bee0', 'attempt': 1})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '7a5f3aa5-6c8d-47a6-9f2b-abe8566ee469', 'example': False}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '7a5f3aa5-6c8d-47a6-9f2b-abe8566ee469', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_nKSSf4bd7KiignisC7YbibEl', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BoOGGFlIsatHf21dbNCYIi6ddfsSz', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--0fdb58b8-ab4e-4503-a0ef-ca56f68a5491-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_nKSSf4bd7KiignisC7YbibEl', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '7a5f3aa5-6c8d-47a6-9f2b-abe8566ee469', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_nKSSf4bd7KiignisC7YbibEl', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BoOGGFlIsatHf21dbNCYIi6ddfsSz', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--0fdb58b8-ab4e-4503-a0ef-ca56f68a5491-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_nKSSf4bd7KiignisC7YbibEl', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '3cbd5b3a-1686-4488-b70a-e097933db0e8', 'tool_call_id': 'call_nKSSf4bd7KiignisC7YbibEl', 'artifact': None, 'status': 'success'}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '7a5f3aa5-6c8d-47a6-9f2b-abe8566ee469', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_nKSSf4bd7KiignisC7YbibEl', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BoOGGFlIsatHf21dbNCYIi6ddfsSz', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--0fdb58b8-ab4e-4503-a0ef-ca56f68a5491-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_nKSSf4bd7KiignisC7YbibEl', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '3cbd5b3a-1686-4488-b70a-e097933db0e8', 'tool_call_id': 'call_nKSSf4bd7KiignisC7YbibEl', 'artifact': None, 'status': 'success'}, {'content': 'The product of 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 13, 'prompt_tokens': 159, 'total_tokens': 172, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BoOGGl2GIHV4BHmrZDx5O6xlCzBvq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--f1824f18-7a3c-476e-8da1-60d68bc4db4c-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 13, 'total_tokens': 172, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]})

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={} response_metadata={} id='f7fb9e79-4f65-48c8-9a83-d99db5548a1d'
# =========================
# content='' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'tool_calls': [{'id': 'call_tjrWTOvTv8CXisgfuFRWnQV3', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BoOIVXv8sMuHjzJ5MlwzATH0BDu3w', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run--1afa64d8-a045-4995-b0dd-81a51a2faa63-0' tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_tjrWTOvTv8CXisgfuFRWnQV3', 'type': 'tool_call'}]
# =========================
# content='6' name='multiply' id='33e9bfb0-ed93-4879-84f1-c851a488757a' tool_call_id='call_tjrWTOvTv8CXisgfuFRWnQV3'
# =========================
# content='The result of multiplying 2 and 3 is 6.' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 14, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 159, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BoOIWIjm1lxhHZSdRCB8OI0TzNfF0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--ed0fb16a-7365-4359-8bc7-e97a8a1a5c50-0'
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can [use `messages` mode](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_messages/) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '1f05640b-ba9a-6c0b-8686-df0bc241a9b3', 'attempt': 1})
# StreamPart(event='messages/metadata', data={'run--d316db0f-9d2c-4deb-8852-70e478b0937b': {'metadata': {'created_by': 'system', 'graph_id': 'agent', 'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca', 'run_attempt': 1, 'langgraph_version': '0.5.0', 'langgraph_api_version': '0.2.72', 'langgraph_plan': 'developer', 'langgraph_host': 'self-hosted', 'langgraph_api_url': 'http://127.0.0.1:2024', 'user-agent': 'langgraph-sdk-py/0.1.72', 'x-request-id': '571d5e80-4cf3-4287-925e-dc65d0afe776', 'langgraph_auth_user_id': '', 'langgraph_request_id': '571d5e80-4cf3-4287-925e-dc65d0afe776', 'run_id': '1f05640b-ba9a-6c0b-8686-df0bc241a9b3', 'thread_id': '893ae7fd-2f8a-4bc0-971f-fda697449439', 'user_id': '', 'langgraph_step': 1, 'langgraph_node': 'assistant', 'langgraph_triggers': ['branch:to:assistant'], 'langgraph_path': ['__pregel_pull', 'assistant'], 'langgraph_checkpoint_ns': 'assistant:f2cc59df-72ee-173d-4d5b-68815ffd0339', 'checkpoint_ns': 'assistant:f2cc59df-72ee-173d-4d5b-68815ffd0339', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}}})
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":2', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":2,"', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":2,"b', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":2,"b":', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":2,"b":3', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, 'type': 'ai', 'name': None, 'id': 'run--d316db0f-9d2c-4deb-8852-70e478b0937b', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/metadata', data={'f9a54171-54eb-4e6a-b2b8-50b88c7b10c1': {'metadata': {'created_by': 'system', 'graph_id': 'agent', 'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca', 'run_attempt': 1, 'langgraph_version': '0.5.0', 'langgraph_api_version': '0.2.72', 'langgraph_plan': 'developer', 'langgraph_host': 'self-hosted', 'langgraph_api_url': 'http://127.0.0.1:2024', 'user-agent': 'langgraph-sdk-py/0.1.72', 'x-request-id': '571d5e80-4cf3-4287-925e-dc65d0afe776', 'langgraph_auth_user_id': '', 'langgraph_request_id': '571d5e80-4cf3-4287-925e-dc65d0afe776', 'run_id': '1f05640b-ba9a-6c0b-8686-df0bc241a9b3', 'thread_id': '893ae7fd-2f8a-4bc0-971f-fda697449439', 'user_id': '', 'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ['branch:to:tools'], 'langgraph_path': ['__pregel_pull', 'tools'], 'langgraph_checkpoint_ns': 'tools:25f6d4d1-c8a6-5569-0880-620e34c3435e', 'LANGSMITH_LANGGRAPH_API_VARIANT': 'local_dev'}}})
# StreamPart(event='messages/complete', data=[{'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'f9a54171-54eb-4e6a-b2b8-50b88c7b10c1', 'tool_call_id': 'call_Z9WLgykAEBSZJjKZcKzKgNEf', 'artifact': None, 'status': 'success'}])
# StreamPart(event='messages/metadata', data={'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8': {'metadata': {'created_by': 'system', 'graph_id': 'agent', 'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca', 'run_attempt': 1, 'langgraph_version': '0.5.0', 'langgraph_api_version': '0.2.72', 'langgraph_plan': 'developer', 'langgraph_host': 'self-hosted', 'langgraph_api_url': 'http://127.0.0.1:2024', 'user-agent': 'langgraph-sdk-py/0.1.72', 'x-request-id': '571d5e80-4cf3-4287-925e-dc65d0afe776', 'langgraph_auth_user_id': '', 'langgraph_request_id': '571d5e80-4cf3-4287-925e-dc65d0afe776', 'run_id': '1f05640b-ba9a-6c0b-8686-df0bc241a9b3', 'thread_id': '893ae7fd-2f8a-4bc0-971f-fda697449439', 'user_id': '', 'langgraph_step': 3, 'langgraph_node': 'assistant', 'langgraph_triggers': ['branch:to:assistant'], 'langgraph_path': ['__pregel_pull', 'assistant'], 'langgraph_checkpoint_ns': 'assistant:6fe2d057-c247-f5aa-0515-ca25f0569519', 'checkpoint_ns': 'assistant:6fe2d057-c247-f5aa-0515-ca25f0569519', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}}})
# StreamPart(event='messages/partial', data=[{'content': '', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying ', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and ', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and 3 is', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and 3 is ', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and 3 is 6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])
# StreamPart(event='messages/partial', data=[{'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'service_tier': 'default'}, 'type': 'ai', 'name': None, 'id': 'run--0ca69f8b-4a18-46bc-8ca6-eaf3bfcf73a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}])

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# You can dig further into the types [here](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages).
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata:
                    finish_reason = response_metadata.get("finish_reason", "N/A")
                    print(f"Response Metadata: Finish Reason - {finish_reason}")
                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 1f056410-613c-6bc8-a043-701912341931
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_wAdCsF5tEkkis3JdSPQ2Ki8e, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# --------------------------------------------------
# AI: The
# --------------------------------------------------
# AI: The result
# --------------------------------------------------
# AI: The result of
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying 2
# --------------------------------------------------
# AI: The result of multiplying 2 and
# --------------------------------------------------
# AI: The result of multiplying 2 and
# --------------------------------------------------
# AI: The result of multiplying 2 and 3
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
